# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import geopandas as gpd

# %%
df = pd.read_csv('Water_Point_Data_Exchange__WPDx-Basic_.csv', dtype='object')

# %%
df.shape
# Out:
# (89717, 52)

# %%
def distance_between_two_points(lat1, lat2, lon1, lon2):

     """
     A procedure to get the distance between two points with latitdues and longitudes
     INPUTS:
        lat1: -> latitude of the first point in degree 
        lat2: -> latitude of the second point in degree 
        lon1: -> longitude of the first point in degree 
        lon2: -> longitude of the second point in degree 
     """    
    # The numpy module contains a function named
    # radians which converts from degrees to radians.

     #lon1a = np.radians(lon1)
    # lon2a = np.radians(lon2)
     lat1a = np.radians(lat1)
     lat2a = np.radians(lat2)
      
    # Haversine formula
    
     dlon = np.radians(lon2 - lon1)
     dlat = np.radians(lat2 - lat1)
     a = np.sin(dlat / 2)**2 + np.cos(lat1a) * np.cos(lat2a) * np.sin(dlon / 2)**2
 
    
     c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
     r = 6371
      
     # calculate the result

     return np.round(c * r, 6)

# %%
df.head()
# Out:
#    row_id                                       #source   #lat_deg   #lon_deg  \
# 0  168928  Federal Ministry of Water Resources, Nigeria  6.2197817   7.006075
# 1  169214  Federal Ministry of Water Resources, Nigeria  6.2172267    6.90776
# 2  169259  Federal Ministry of Water Resources, Nigeria  5.8981991  6.8390944
# 3  207839  Federal Ministry of Water Resources, Nigeria  7.8310683  8.8338717
# 4  208157  Federal Ministry of Water Resources, Nigeria  7.0277082  8.5691409
#
#              #report_date #status_id                   #water_source  \
# 0  05/27/2015 12:00:00 AM        Yes  Improved Tube well or borehole
# 1  05/22/2015 12:00:00 AM         No  Improved Tube well or borehole
# 2  05/03/2015 12:00:00 AM        Yes  Improved Tube well or borehole
# 3  08/27/2015 12:00:00 AM         No  Improved Tube well or borehole
# 4  08/23/2015 12:00:00 AM        Yes  Improved Tube well or borehole
#
#   #water_source_clean #water_tech_clean #water_tech  ... clean_adm2  \
# 0            Borehole   Mechanized Pump   Motorised  ...   AwkaSout
# 1            Borehole   Mechanized Pump   Motorised  ...        Oyi
# 2            Borehole         Hand Pump   Hand pump  ...   NnewiSou
# 3            Borehole         Hand Pump      Manual  ...       Guma
# 4            Borehole         Hand Pump   Hand pump  ...   Konshish
#
#   clean_adm3 water_tech_original           water_source_original  \
# 0        NaN           motorised  improved tube well or borehole
# 1        NaN           motorised  improved tube well or borehole
# 2        NaN           hand pump  improved tube well or borehole
# 3        NaN              manual  improved tube well or borehole
# 4        NaN           hand pump  improved tube well or borehole
#
#   lat_deg_original lon_deg_original      management_clean  \
# 0              NaN              NaN                 Other
# 1              NaN              NaN                   NaN
# 2              NaN              NaN  Health Care Facility
# 3              NaN              NaN                   NaN
# 4              NaN              NaN                 Other
#
#                                management_original water_source_category  \
# 0                                            other                  Well
# 1                                              NaN                  Well
# 2  institutional management - health care facility                  Well
# 3                                              NaN                  Well
# 4                                            other                  Well
#
#   water_tech_category
# 0     Mechanized Pump
# 1     Mechanized Pump
# 2           Hand Pump
# 3           Hand Pump
# 4           Hand Pump
#
# [5 rows x 52 columns]

# %%
# Drop columns  with all NaN, single values, irrelevant columns
df.dropna(how='all', axis=1, inplace=True)
cols_to_drop = ['row_id', '#source', '#facility_type', '#report_date', '#country_name',  '#data_lnk', '#converted', '#country_id', '#install_year', 'created_timestamp', 'updated', 'public_data_source', 'water_tech_category', 'water_tech_original', 'count', 'management_original', 'public_data_source', 'clean_country_id', 'clean_country_name']
df.drop(cols_to_drop, axis =1, inplace=True)
df.shape
# Out:
# (89717, 29)

# %%
# Drop more columns with duplication, majority of NaN
cols_to_drop1 = ['#adm3', '#water_source', '#water_tech', '#installer', '#management', '#fecal_coliform_value', '#activity_id', '#scheme_id', '#orig_lnk', 'clean_adm3', 'water_source_original']
df.drop(cols_to_drop1, axis =1, inplace=True)
df.shape
# Out:
# (89717, 18)

# %%
df.columns
# Out:
# Index(['#lat_deg', '#lon_deg', '#status_id', '#water_source_clean',
#        '#water_tech_clean', '#adm1', '#adm2', '#pay', '#status',
#        '#subjective_quality', '#notes', '#photo_lnk', 'lat_lon_deg',
#        'New Georeferenced Column', 'clean_adm1', 'clean_adm2',
#        'management_clean', 'water_source_category'],
#       dtype='object')

# %%
# Drop more

# %%
df['clean_adm1'].head()
#df['#water_tech'].value_counts(dropna=False)
# Out:
# 0    Anambra
# 1    Anambra
# 2    Anambra
# 3      Benue
# 4      Benue
# Name: clean_adm1, dtype: object

# %%
df['water_source_original'].isnull().sum().sum()
# Out:
# 7

# %%
# Rename columns with # prefixes
mapper = {'#lat_deg': 'latitude', '#lon_deg': 'longitude', '#status_id' :'status_id', '#water_source_clean': 'water_source', '#water_tech_clean': 'water_technology', '#adm1': 'state',
       '#adm2': 'lga', '#pay': 'pay', '#status': 'status', '#subjective_quality': 'subjective_quality', '#notes': 'location', '#photo_lnk': 'photo_lnk','clean_adm1': 'state' , 'clean_adm2':'lga'}
df= df.rename(columns=mapper)

# %%
df.head()
# Out:
#     latitude  longitude status_id water_source water_technology    state  \
# 0  6.2197817   7.006075       Yes     Borehole  Mechanized Pump  Anambra
# 1  6.2172267    6.90776        No     Borehole  Mechanized Pump  Anambra
# 2  5.8981991  6.8390944       Yes     Borehole        Hand Pump  Anambra
# 3  7.8310683  8.8338717        No     Borehole        Hand Pump    Benue
# 4  7.0277082  8.5691409       Yes     Borehole        Hand Pump    Benue
#
#          lga pay                              status   subjective_quality  \
# 0    Njikoka  No             Functional (and in use)   Acceptable quality
# 1        Oyi  No  Non-functional Technical breakdown   Acceptable quality
# 2      Ihala  No             Functional (and in use)   Acceptable quality
# 3       Guma  No  Non-functional Technical breakdown  No because of Taste
# 4  Konshisha  No             Functional (and in use)   Acceptable quality
#
#            location                                          photo_lnk  \
# 0          Etiti  1  https://akvoflow-55.s3.amazonaws.com/images/8b...
# 1   Ajakpani Umunya  https://akvoflow-55.s3.amazonaws.com/images/37...
# 2  Ubahumonum Okija                                                NaN
# 3            Iordye                                                NaN
# 4             Manta                                                NaN
#
#                 lat_lon_deg     New Georeferenced Column    state       lga  \
# 0   (6.2197817°, 7.006075°)   POINT (7.006075 6.2197817)  Anambra  AwkaSout
# 1    (6.2172267°, 6.90776°)    POINT (6.90776 6.2172267)  Anambra       Oyi
# 2  (5.8981991°, 6.8390944°)  POINT (6.8390944 5.8981991)  Anambra  NnewiSou
# 3  (7.8310683°, 8.8338717°)  POINT (8.8338717 7.8310683)    Benue      Guma
# 4  (7.0277082°, 8.5691409°)  POINT (8.5691409 7.0277082)    Benue  Konshish
#
#        management_clean water_source_category
# 0                 Other                  Well
# 1                   NaN                  Well
# 2  Health Care Facility                  Well
# 3                   NaN                  Well
# 4                 Other                  Well

# %%
df['latitude'] = df['latitude'].astype('float')
df['longitude'] = df['longitude'].astype('float')

# %%
# Create  hypothetical resident's latitude and longitude
np.random.seed(0) 
#df.insert(0, 'resident_latitude', df.latitude + 0.0051*np.random.rand(df.shape[0]))
df.insert(1, 'resident_longitude', df.longitude + 0.00982*np.random.rand(df.shape[0]))

# %%
df.head()
# Out:
#    resident_latitude  resident_longitude  latitude  longitude status_id  \
# 0           6.222581            7.011464  6.219782   7.006075       Yes
# 1           6.220874            6.914783  6.217227   6.907760        No
# 2           5.901273            6.845014  5.898199   6.839094       Yes
# 3           7.833847            8.839222  7.831068   8.833872        No
# 4           7.029869            8.573301  7.027708   8.569141       Yes
#
#   water_source water_technology    state        lga pay  ...  \
# 0     Borehole  Mechanized Pump  Anambra    Njikoka  No  ...
# 1     Borehole  Mechanized Pump  Anambra        Oyi  No  ...
# 2     Borehole        Hand Pump  Anambra      Ihala  No  ...
# 3     Borehole        Hand Pump    Benue       Guma  No  ...
# 4     Borehole        Hand Pump    Benue  Konshisha  No  ...
#
#     subjective_quality          location  \
# 0   Acceptable quality          Etiti  1
# 1   Acceptable quality   Ajakpani Umunya
# 2   Acceptable quality  Ubahumonum Okija
# 3  No because of Taste            Iordye
# 4   Acceptable quality             Manta
#
#                                            photo_lnk  \
# 0  https://akvoflow-55.s3.amazonaws.com/images/8b...
# 1  https://akvoflow-55.s3.amazonaws.com/images/37...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                 lat_lon_deg     New Georeferenced Column    state       lga  \
# 0   (6.2197817°, 7.006075°)   POINT (7.006075 6.2197817)  Anambra  AwkaSout
# 1    (6.2172267°, 6.90776°)    POINT (6.90776 6.2172267)  Anambra       Oyi
# 2  (5.8981991°, 6.8390944°)  POINT (6.8390944 5.8981991)  Anambra  NnewiSou
# 3  (7.8310683°, 8.8338717°)  POINT (8.8338717 7.8310683)    Benue      Guma
# 4  (7.0277082°, 8.5691409°)  POINT (8.5691409 7.0277082)    Benue  Konshish
#
#        management_clean water_source_category  longiude
# 0                 Other                  Well  7.006075
# 1                   NaN                  Well  6.907760
# 2  Health Care Facility                  Well  6.839094
# 3                   NaN                  Well  8.833872
# 4                 Other                  Well  8.569141
#
# [5 rows x 21 columns]

# %%
# Create an id column
df.drop('id', axis=1, inplace=True)
df.insert(0, 'id', list(range(1, 1+df.shape[0])))

# %%
df.head()
# Out:
#    id  resident_latitude  resident_longitude  latitude  longitude status_id  \
# 0   1           6.222581            7.011464  6.219782   7.006075       Yes
# 1   2           6.220874            6.914783  6.217227   6.907760        No
# 2   3           5.901273            6.845014  5.898199   6.839094       Yes
# 3   4           7.833847            8.839222  7.831068   8.833872        No
# 4   5           7.029869            8.573301  7.027708   8.569141       Yes
#
#   water_source water_technology    state        lga  ...   subjective_quality  \
# 0     Borehole  Mechanized Pump  Anambra    Njikoka  ...   Acceptable quality
# 1     Borehole  Mechanized Pump  Anambra        Oyi  ...   Acceptable quality
# 2     Borehole        Hand Pump  Anambra      Ihala  ...   Acceptable quality
# 3     Borehole        Hand Pump    Benue       Guma  ...  No because of Taste
# 4     Borehole        Hand Pump    Benue  Konshisha  ...   Acceptable quality
#
#            location                                          photo_lnk  \
# 0          Etiti  1  https://akvoflow-55.s3.amazonaws.com/images/8b...
# 1   Ajakpani Umunya  https://akvoflow-55.s3.amazonaws.com/images/37...
# 2  Ubahumonum Okija                                                NaN
# 3            Iordye                                                NaN
# 4             Manta                                                NaN
#
#                 lat_lon_deg     New Georeferenced Column    state       lga  \
# 0   (6.2197817°, 7.006075°)   POINT (7.006075 6.2197817)  Anambra  AwkaSout
# 1    (6.2172267°, 6.90776°)    POINT (6.90776 6.2172267)  Anambra       Oyi
# 2  (5.8981991°, 6.8390944°)  POINT (6.8390944 5.8981991)  Anambra  NnewiSou
# 3  (7.8310683°, 8.8338717°)  POINT (8.8338717 7.8310683)    Benue      Guma
# 4  (7.0277082°, 8.5691409°)  POINT (8.5691409 7.0277082)    Benue  Konshish
#
#        management_clean water_source_category  longiude
# 0                 Other                  Well  7.006075
# 1                   NaN                  Well  6.907760
# 2  Health Care Facility                  Well  6.839094
# 3                   NaN                  Well  8.833872
# 4                 Other                  Well  8.569141
#
# [5 rows x 22 columns]

# %%
df.drop('longiude', axis=1, inplace=True)

# %%
df.head()
# Out:
#    id  resident_latitude  resident_longitude  latitude  longitude status_id  \
# 0   1           6.222581            7.011464  6.219782   7.006075       Yes
# 1   2           6.220874            6.914783  6.217227   6.907760        No
# 2   3           5.901273            6.845014  5.898199   6.839094       Yes
# 3   4           7.833847            8.839222  7.831068   8.833872        No
# 4   5           7.029869            8.573301  7.027708   8.569141       Yes
#
#   water_source water_technology    state        lga  ...  \
# 0     Borehole  Mechanized Pump  Anambra    Njikoka  ...
# 1     Borehole  Mechanized Pump  Anambra        Oyi  ...
# 2     Borehole        Hand Pump  Anambra      Ihala  ...
# 3     Borehole        Hand Pump    Benue       Guma  ...
# 4     Borehole        Hand Pump    Benue  Konshisha  ...
#
#                                status   subjective_quality          location  \
# 0             Functional (and in use)   Acceptable quality          Etiti  1
# 1  Non-functional Technical breakdown   Acceptable quality   Ajakpani Umunya
# 2             Functional (and in use)   Acceptable quality  Ubahumonum Okija
# 3  Non-functional Technical breakdown  No because of Taste            Iordye
# 4             Functional (and in use)   Acceptable quality             Manta
#
#                                            photo_lnk  \
# 0  https://akvoflow-55.s3.amazonaws.com/images/8b...
# 1  https://akvoflow-55.s3.amazonaws.com/images/37...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                 lat_lon_deg     New Georeferenced Column    state       lga  \
# 0   (6.2197817°, 7.006075°)   POINT (7.006075 6.2197817)  Anambra  AwkaSout
# 1    (6.2172267°, 6.90776°)    POINT (6.90776 6.2172267)  Anambra       Oyi
# 2  (5.8981991°, 6.8390944°)  POINT (6.8390944 5.8981991)  Anambra  NnewiSou
# 3  (7.8310683°, 8.8338717°)  POINT (8.8338717 7.8310683)    Benue      Guma
# 4  (7.0277082°, 8.5691409°)  POINT (8.5691409 7.0277082)    Benue  Konshish
#
#        management_clean water_source_category
# 0                 Other                  Well
# 1                   NaN                  Well
# 2  Health Care Facility                  Well
# 3                   NaN                  Well
# 4                 Other                  Well
#
# [5 rows x 21 columns]

# %%
# Create a column for distance between the resident and nearest water point
distance_in_km = []
for row in df.itertuples(index=False):
    distance_in_km.append(
       distance_between_two_points(row.resident_latitude, row.latitude, row.resident_longitude, row.longitude)
       )

df['distance_in_km'] = distance_in_km

# %%
# fill missing values 
df= df.fillna(method='bfill')
df= df.fillna(method='ffill')
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (89717, 23)

# %%
# add hypothetical population column to the dataframe 
np.random.seed(0)
df.insert(22, 'population', np.random.randint(1500, 2830, size= df.shape[0]))

# %%
# create a sqlite database engine using sqlalchemy
database_filepath = 'water_points.db'
engine = create_engine(f'sqlite:///{database_filepath}')
# save the df in a table if exists replace
df.to_sql('etlTable', engine, index=False, if_exists='replace')

# %%
df.head()
# Out:
#    id  resident_latitude  resident_longitude  latitude  longitude status_id  \
# 0   1           6.222581            7.011464  6.219782   7.006075       Yes
# 1   2           6.220874            6.914783  6.217227   6.907760        No
# 2   3           5.901273            6.845014  5.898199   6.839094       Yes
# 3   4           7.833847            8.839222  7.831068   8.833872        No
# 4   5           7.029869            8.573301  7.027708   8.569141       Yes
#
#   water_source water_technology    state        lga  ...          location  \
# 0     Borehole  Mechanized Pump  Anambra    Njikoka  ...          Etiti  1
# 1     Borehole  Mechanized Pump  Anambra        Oyi  ...   Ajakpani Umunya
# 2     Borehole        Hand Pump  Anambra      Ihala  ...  Ubahumonum Okija
# 3     Borehole        Hand Pump    Benue       Guma  ...            Iordye
# 4     Borehole        Hand Pump    Benue  Konshisha  ...             Manta
#
#                                            photo_lnk  \
# 0  https://akvoflow-55.s3.amazonaws.com/images/8b...
# 1  https://akvoflow-55.s3.amazonaws.com/images/37...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                 lat_lon_deg     New Georeferenced Column    state       lga  \
# 0   (6.2197817°, 7.006075°)   POINT (7.006075 6.2197817)  Anambra  AwkaSout
# 1    (6.2172267°, 6.90776°)    POINT (6.90776 6.2172267)  Anambra       Oyi
# 2  (5.8981991°, 6.8390944°)  POINT (6.8390944 5.8981991)  Anambra  NnewiSou
# 3  (7.8310683°, 8.8338717°)  POINT (8.8338717 7.8310683)    Benue      Guma
# 4  (7.0277082°, 8.5691409°)  POINT (8.5691409 7.0277082)    Benue  Konshish
#
#        management_clean water_source_category distance_in_km population
# 0                 Other                  Well       0.672137       2141
# 1                   NaN                  Well       0.875902       2195
# 2  Health Care Facility                  Well       0.738556       2330
# 3                   NaN                  Well       0.665510       2382
# 4                 Other                  Well       0.518188       2401
#
# [5 rows x 23 columns]
